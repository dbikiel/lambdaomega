# %% [markdown]
# Using the sdeint package, we will simulate realizations of the lambda-omega system with different levels of noise in the x coordinate and different levels of lambda and b parameters, obtaining the same cycle limits.

# %%
#Number crunching, data and plotting
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set();

# Numerical integration
import sdeint
from scipy.integrate import solve_ivp

# Beatiful progress bars
from tqdm import tqdm, auto
from tqdm.notebook import tqdm

#load, save and compress data
import bz2
import pickle
import _pickle as cPickle

#other libraries
import pathlib

# %% [markdown]
# The following function creates a realization with $\Lambda$-$\Omega$ parameters (l, o, a, b), noise sigma (gaussian with $\mu$= 0 and $\sigma$ = sigma). The realization is run from 0 to tfin with a timestep of tstep.

# %%
def realization_with_params_and_time(l, o, a, b, sigma, tfin, tstep):
    tspan = np.linspace(0.0, tfin, int(tfin/tstep + 1))
    X0 = np.array([1, 0.0])

    params_F = [l, o, a, b]

    params_G = [np.diag([sigma, 0.0])]

    return sdeint.itoint(close(F,*params_F) , close(G, *params_G), X0, tspan)

def close(func, *args):
    def newfunc(x, t):
        return func(x, t, *args)
    return newfunc

def F(X, t, l, o, a, b):
    
    x = X[0]
    y = X[1]
    
    r2 = x**2 + y**2
    
    dx = x*(l - b*r2) - y*(o + a*r2)
    dy = x*(o + a*r2) + y*(l - b*r2)
    
    return np.array([dx, dy])

def G(X, t, B):
    return B

# %% [markdown]
# The following function calculate the mean trajectory for the ensemble of trajectories.

# %%
def mean_trajectory(trajs):
    N = len(trajs)
    x_vals = np.zeros((len(trajs[0]),N))
    y_vals = np.zeros((len(trajs[0]),N))
    #Extract x coordinate
    for i, x in enumerate(trajs):
        x_vals[:,i] = x[:,0]
        y_vals[:,i] = x[:,1]    
    #calculate mean trajectory
    mean_traj_x = np.mean(x_vals, axis = 1)
    mean_traj_y = np.mean(y_vals, axis = 1)
    
    #calculates the mean root mean square deviation for the complete set
    #rms = 0
    #x_diff = (x_vals - mean_traj_x.reshape(len(x_vals),1))**2
    #y_diff = (y_vals - mean_traj_y.reshape(len(y_vals),1))**2
    #return [mean_traj_x, mean_traj_y, x_diff, y_diff]
    return [mean_traj_x, mean_traj_y]

# %%
file = pathlib.Path('trajectories.pbz2')
if file.exists ():
    print('Trajectories already calculated, loading and decompressing data...')
    rs_lam = bz2.BZ2File(file, 'rb')
    rs_lam = cPickle.load(rs_lam)
# Out:
# Trajectories already calculated, loading and decompressing data...

# %% [markdown]
# Initializes and perform 5000 realizations for each combination of $\lambda$ and $\sigma$, saving the result in rs_lam dictionary.

# %%
#check if file exists
file = pathlib.Path('trajectories.pbz2')
if file.exists ():
    print('Trajectories already calculated, loading and decompressing data...')
    rs_lam = bz2.BZ2File(file, 'rb')
    rs_lam = cPickle.load(rs_lam)
else:
    #calculate the trajectories
    np.random.seed(42)

    lams = [0.1, 0.25, 1, 2.5, 10]
    sigmas = [0.01, 0.05, 0.1, 0.5, 1]

    rs_lam = {}

    for lam in tqdm(lams):
        for sigma in tqdm(sigmas, leave = False):
            rs = []
            for _ in tqdm(range(5000), leave = False):
                r = realization_with_params_and_time(lam, 1, 1, lam, sigma, 10, 0.01)
                rs.append(r)
            #print(lam, sigma, 'Done!')
            rs_lam[(lam, sigma)] = rs

# %% [markdown]
# In order to avoid the recalculation, save and compress the data:

# %%
#Compress and save the data:
#with bz2.BZ2File('trajectories.pbz2', 'w') as f: 
#    cPickle.dump(rs_lam, f)

# %% [markdown]
# We will average all the trajectories for each combination, obtaining a "mean trajectory". This mean path will be converge from the original cycle to mean 0, due to the desynchronization produced by the white noise. The dynamics of this transformation encodes the amount of noise and the value of lambda. First we will observe how the trajectory evolves in time for different values of $\lambda$ keeping $\sigma$ constant.

# %%
mean_trajectories_r = {}
for r in rs_lam.keys():
    mean_trajectories_r[r] = mean_trajectory(rs_lam[r])

# %%
fig, axs = plt.subplots(5, figsize = (10,30))

t = np.linspace(0,10, int(10/0.01) + 1)

for i, r in enumerate(mean_trajectories_r):
    if r[0] == 0.1:
        color = 'blue'
    elif r[0] == 0.25:
        color = 'red'
    elif r[0] == 1:
        color = 'green'
    elif r[0] == 2.5:
        color = 'magenta'
    elif r[0] == 10:
        color = 'black'
        
    if r[1] == 0.01:
        axs[0].plot(t, mean_trajectories_r[r][0]**2 + mean_trajectories_r[r][1]**2, label = r[0], color = color)
        axs[0].title.set_text('Noise: ' + str(r[1]))
    if r[1] == 0.05:
        axs[1].plot(t, mean_trajectories_r[r][0]**2 + mean_trajectories_r[r][1]**2, label = r[0], color = color)
        axs[1].title.set_text('Noise: ' + str(r[1]))
    if r[1] == 0.1:
        axs[2].plot(t, mean_trajectories_r[r][0]**2 + mean_trajectories_r[r][1]**2, label = r[0], color = color)
        axs[2].title.set_text('Noise: ' + str(r[1]))
    if r[1] == 0.5:
        axs[3].plot(t, mean_trajectories_r[r][0]**2 + mean_trajectories_r[r][1]**2, label = r[0], color = color)
        axs[3].title.set_text('Noise: ' + str(r[1]))
    if r[1] == 1:
        axs[4].plot(t, mean_trajectories_r[r][0]**2 + mean_trajectories_r[r][1]**2, label = r[0], color = color)
        axs[4].title.set_text('Noise: ' + str(r[1]))

for i in range(5):
    axs[i].legend()

plt.show()

# %% [markdown]
# It is possible to observe that increasing noise produces steeper decays. In addition, at high $\lambda$, some oscillatory behavior stills present.

# %% [markdown]
# Now we can observe how the trajectories evolve in time for each $\sigma$ value, keeping constant $\lambda$

# %%
fig, axs = plt.subplots(5, figsize = (10,30))

t = np.linspace(0,10, int(10/0.01) + 1)

for i, r in enumerate(mean_trajectories_r):
    if r[1] == 0.01:
        color = 'blue'
    elif r[1] == 0.05:
        color = 'red'
    elif r[1] == 0.1:
        color = 'green'
    elif r[1] == 0.5:
        color = 'magenta'
    elif r[1] == 1:
        color = 'black'
        
    if r[0] == 0.1:
        axs[0].plot(t, mean_trajectories_r[r][0]**2 + mean_trajectories_r[r][1]**2, label = r[1], color = color)
        axs[0].title.set_text('Lambda: ' + str(r[0]))
    if r[0] == 0.25:
        axs[1].plot(t, mean_trajectories_r[r][0]**2 + mean_trajectories_r[r][1]**2, label = r[1], color = color)
        axs[1].title.set_text('Lambda: ' + str(r[0]))
    if r[0] == 1:
        axs[2].plot(t, mean_trajectories_r[r][0]**2 + mean_trajectories_r[r][1]**2, label = r[1], color = color)
        axs[2].title.set_text('Lambda: ' + str(r[0]))
    if r[0] == 2.5:
        axs[3].plot(t, mean_trajectories_r[r][0]**2 + mean_trajectories_r[r][1]**2, label = r[1], color = color)
        axs[3].title.set_text('Lambda: ' + str(r[0]))
    if r[0] == 10:
        axs[4].plot(t, mean_trajectories_r[r][0]**2 + mean_trajectories_r[r][1]**2, label = r[1], color = color)
        axs[4].title.set_text('Lambda: ' + str(r[0]))

for i in range(5):
    axs[i].legend()

plt.show()

# %% [markdown]
# To visualize the process, let's plot what happen to an ensemble of trajectories:

# %%
fig, ax = plt.subplots()
for r in rs_lam[(0.1, 0.1)]:
    ax.plot(t, r[:,0], alpha = 0.01, color = 'green')
ax.plot(t, mean_trajectories_r[(0.1,0.1)][0], color = 'black')
ax.set(xlabel = 't', ylabel = 'x(t)')
plt.show()

# %% [markdown]
# In order to measure the departure from the limit cycle, we can compute the error of the trajectory respect to the ideal phase diagram. To do that, we first digitize the phase diagram and calculate the distribution of points. Similarly, we digitize each trajectory and compute the rms deviation respect the limit cycle.

# %%
def digitize(trajectory, bins):
    x = trajectory[:,0]
    y = trajectory[:,1]
    counts, xedges, yedges = np.histogram2d(x, y, bins = bins)
    return counts/len(x)

def error(target_counts, noise_counts):
    return np.sqrt(sum(sum((target_counts - noise_counts)**2)))

bins = np.linspace(-1.1,1.1,101)

# %%
theta = np.linspace(0, 2*np.pi, 5001)
x_target = 1.0*np.cos(theta)
y_target = 1.0*np.sin(theta)
target_trajectory = np.hstack((x_target.reshape(x_target.size,1), y_target.reshape(y_target.size,1)))

# %%
target_digitized = digitize(target_trajectory, bins)

# %%
def error_traj(target_digitized, trajectories):
    error_vals = []
    for t in trajectories:
        tt = np.hstack((t[:,0].reshape(t[:,0].size,1), t[:,1].reshape(t[:,1].size,1)))
        error_vals.append(error(target_digitized, digitize(tt, bins)))
    return np.array(error_vals)

# %%
error_dict = {}
for rs in tqdm(rs_lam.keys()):
    error_dict[rs] = error_traj(target_digitized, rs_lam[rs])

# %% [markdown]
# Once each ensemble ($\lambda$, $\sigma$) is computed, we can plot the distribution to see patterns.

# %%
lam_list = []
noise_list = []
error_list = []

for rs in error_dict.keys():
    error_list = error_list + list(error_dict[rs])
    lam_list = lam_list + len(error_dict[rs])*[rs[0]]
    noise_list = noise_list + len(error_dict[rs])*[rs[1]]

# %%
df = pd.DataFrame({'lambdas': lam_list, 'noise': noise_list, 'error': error_list})

# %%
plt.figure(figsize = (20,10))
sns.pointplot(x = 'lambdas', y = 'error', data= df, hue = 'noise', ci = 95, capsize = 0.5)
plt.show()

# %% [markdown]
# # Trying an Autoencoder to characterize each trajectory

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
lam_list = []
noise_list = []
traj_list = np.empty((125000,1001))

k = 0
for rs in rs_lam.keys():
    lam_list = lam_list + len(rs_lam[rs])*[rs[0]]
    noise_list = noise_list + len(rs_lam[rs])*[rs[1]]
    for i in range(5000):
        traj_list[k,:] = rs_lam[rs][i][:,0]
        k += 1
    print(rs)
# Out:
# (0.1, 0.01)
# (0.1, 0.05)
# (0.1, 0.1)
# (0.1, 0.5)
# (0.1, 1)
# (0.25, 0.01)
# (0.25, 0.05)
# (0.25, 0.1)
# (0.25, 0.5)
# (0.25, 1)
# (1, 0.01)
# (1, 0.05)
# (1, 0.1)
# (1, 0.5)
# (1, 1)
# (2.5, 0.01)
# (2.5, 0.05)
# (2.5, 0.1)
# (2.5, 0.5)
# (2.5, 1)
# (10, 0.01)
# (10, 0.05)
# (10, 0.1)
# (10, 0.5)
# (10, 1)

# %%
lam_list = np.array(lam_list)
noise_list = np.array(noise_list)

# %%
import umap

# %%
reducer = umap.UMAP(verbose = True)

# %%
embedding = reducer.fit_transform(traj_list)
# Out:
# UMAP(a=None, angular_rp_forest=False, b=None,
#      force_approximation_algorithm=False, init='spectral', learning_rate=1.0,
#      local_connectivity=1.0, low_memory=False, metric='euclidean',
#      metric_kwds=None, min_dist=0.1, n_components=2, n_epochs=None,
#      n_neighbors=15, negative_sample_rate=5, output_metric='euclidean',
#      output_metric_kwds=None, random_state=None, repulsion_strength=1.0,
#      set_op_mix_ratio=1.0, spread=1.0, target_metric='categorical',
#      target_metric_kwds=None, target_n_neighbors=-1, target_weight=0.5,
#      transform_queue_size=4.0, transform_seed=42, unique=False, verbose=True)
# Construct fuzzy simplicial set
# Wed Jun  3 20:07:19 2020 Finding Nearest Neighbors
# Wed Jun  3 20:07:19 2020 Building RP forest with 23 trees
# Wed Jun  3 20:07:45 2020 NN descent for 17 iterations
# 	 0  /  17
# 	 1  /  17
# 	 2  /  17
# 	 3  /  17
# 	 4  /  17
# 	 5  /  17
# 	 6  /  17
# 	 7  /  17
# ...

# %%
embedding.shape
# Out:
# (125000, 2)

# %%
lam_noise_list = []
for i in range(25):
    lam_noise_list = lam_noise_list + 5000*[i]

lam_val_list = []
for i in range(5):
    lam_val_list = lam_val_list + 5*5000*[i]

# %%
plt.figure(figsize = (20,10))
plt.scatter(embedding[:, 0], embedding[:, 1], c=[sns.color_palette("hls", 5)[x] for x in lam_val_list], alpha = 0.3, s=4)
plt.gca().set_aspect('equal', 'datalim')

# %%
plt.figure(figsize = (20,10))
#plt.scatter(embedding[:, 0], embedding[:, 1], c='blue', alpha = 0.2, s=2)
plt.scatter(embedding[(lam_list == 0.1) & (noise_list == 0.01), 0], embedding[(lam_list == 0.1) & (noise_list == 0.01), 1], c='red', alpha = 0.2, s=2)
plt.scatter(embedding[(lam_list == 0.25) & (noise_list == 0.01), 0], embedding[(lam_list == 0.25) & (noise_list == 0.01), 1], c='green', alpha = 0.2, s=2)
plt.scatter(embedding[(lam_list == 1) & (noise_list == 0.01), 0], embedding[(lam_list == 1) & (noise_list == 0.01), 1], c='blue', alpha = 0.2, s=2)
plt.scatter(embedding[(lam_list == 2.5) & (noise_list == 0.01), 0], embedding[(lam_list == 2.5) & (noise_list == 0.01), 1], c='blue', alpha = 0.2, s=2)
plt.scatter(embedding[(lam_list == 10) & (noise_list == 0.01), 0], embedding[(lam_list == 10) & (noise_list == 0.01), 1], c='black', alpha = 0.2, s=2)
plt.gca().set_aspect('equal', 'datalim')

# %% [markdown]
# # Keeping only noise = 0.1

# %%
target = lam_list[noise_list == 0.1]
data = traj_list[noise_list == 0.1,:]

# %%
data.shape
# Out:
# (25000, 1001)

# %%
embedding_01 = umap.UMAP(n_neighbors=5, verbose = True).fit_transform(data)
# Out:
# UMAP(a=None, angular_rp_forest=False, b=None,
#      force_approximation_algorithm=False, init='spectral', learning_rate=1.0,
#      local_connectivity=1.0, low_memory=False, metric='euclidean',
#      metric_kwds=None, min_dist=0.1, n_components=2, n_epochs=None,
#      n_neighbors=5, negative_sample_rate=5, output_metric='euclidean',
#      output_metric_kwds=None, random_state=None, repulsion_strength=1.0,
#      set_op_mix_ratio=1.0, spread=1.0, target_metric='categorical',
#      target_metric_kwds=None, target_n_neighbors=-1, target_weight=0.5,
#      transform_queue_size=4.0, transform_seed=42, unique=False, verbose=True)
# Construct fuzzy simplicial set
# Thu Jun  4 08:01:09 2020 Finding Nearest Neighbors
# Thu Jun  4 08:01:09 2020 Building RP forest with 13 trees
# Thu Jun  4 08:01:12 2020 NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	 5  /  15
# 	 6  /  15
# 	 7  /  15
# ...

# %%
target_label = np.array([5000*[i] for i in range(5)]).ravel()

# %%
fig, ax = plt.subplots(1, figsize=(14, 10))
plt.scatter(*embedding_01.T, s=0.3, c=target_label, cmap='Spectral', alpha=1.0)
plt.setp(ax, xticks=[], yticks=[])
cbar = plt.colorbar(boundaries=np.arange(6)-0.5)
cbar.set_ticks(np.arange(5))
cbar.set_ticklabels(['0.1','0.25','1','2.5','10'])
plt.title('noise 0.1 Embedded via UMAP');

# %% [markdown]
# # supervised UMAP

# %%
embedding_01_super = umap.UMAP(verbose = True).fit_transform(data, y = target_label)
# Out:
# UMAP(a=None, angular_rp_forest=False, b=None,
#      force_approximation_algorithm=False, init='spectral', learning_rate=1.0,
#      local_connectivity=1.0, low_memory=False, metric='euclidean',
#      metric_kwds=None, min_dist=0.1, n_components=2, n_epochs=None,
#      n_neighbors=15, negative_sample_rate=5, output_metric='euclidean',
#      output_metric_kwds=None, random_state=None, repulsion_strength=1.0,
#      set_op_mix_ratio=1.0, spread=1.0, target_metric='categorical',
#      target_metric_kwds=None, target_n_neighbors=-1, target_weight=0.5,
#      transform_queue_size=4.0, transform_seed=42, unique=False, verbose=True)
# Construct fuzzy simplicial set
# Thu Jun  4 08:08:27 2020 Finding Nearest Neighbors
# Thu Jun  4 08:08:27 2020 Building RP forest with 13 trees
# Thu Jun  4 08:08:30 2020 NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	 5  /  15
# Thu Jun  4 08:08:35 2020 Finished Nearest Neighbor Search
# ...

# %%
fig, ax = plt.subplots(1, figsize=(14, 10))
plt.scatter(*embedding_01_super.T, s=0.3, c=target_label, cmap='Spectral', alpha=1.0)
plt.setp(ax, xticks=[], yticks=[])
cbar = plt.colorbar(boundaries=np.arange(6)-0.5)
cbar.set_ticks(np.arange(5))
cbar.set_ticklabels(['0.1','0.25','1','2.5','10'])
plt.title('noise 0.1 Embedded via UMAP');

# %%
target_05 = lam_list[noise_list == 0.5]
data_05 = traj_list[noise_list == 0.5,:]

# %%
plt.plot(target_05)

# %%
embedding_05_super = umap.UMAP(verbose = True).fit_transform(data_05, y = target_label)
# Out:
# UMAP(a=None, angular_rp_forest=False, b=None,
#      force_approximation_algorithm=False, init='spectral', learning_rate=1.0,
#      local_connectivity=1.0, low_memory=False, metric='euclidean',
#      metric_kwds=None, min_dist=0.1, n_components=2, n_epochs=None,
#      n_neighbors=15, negative_sample_rate=5, output_metric='euclidean',
#      output_metric_kwds=None, random_state=None, repulsion_strength=1.0,
#      set_op_mix_ratio=1.0, spread=1.0, target_metric='categorical',
#      target_metric_kwds=None, target_n_neighbors=-1, target_weight=0.5,
#      transform_queue_size=4.0, transform_seed=42, unique=False, verbose=True)
# Construct fuzzy simplicial set
# Thu Jun  4 08:17:16 2020 Finding Nearest Neighbors
# Thu Jun  4 08:17:16 2020 Building RP forest with 13 trees
# Thu Jun  4 08:17:18 2020 NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	 5  /  15
# 	 6  /  15
# Thu Jun  4 08:17:22 2020 Finished Nearest Neighbor Search
# ...

# %%
fig, ax = plt.subplots(1, figsize=(14, 10))
plt.scatter(*embedding_05_super.T, s=0.3, c=target_label, cmap='Spectral', alpha=1.0)
plt.setp(ax, xticks=[], yticks=[])
cbar = plt.colorbar(boundaries=np.arange(6)-0.5)
cbar.set_ticks(np.arange(5))
cbar.set_ticklabels(['0.1','0.25','1','2.5','10'])
plt.title('noise 0.5 Embedded via UMAP');

# %%
target_001 = lam_list[noise_list == 0.01]
data_001 = traj_list[noise_list == 0.01,:]

# %%
embedding_001_super = umap.UMAP(verbose = True).fit_transform(data_001, y = target_label)
# Out:
# UMAP(a=None, angular_rp_forest=False, b=None,
#      force_approximation_algorithm=False, init='spectral', learning_rate=1.0,
#      local_connectivity=1.0, low_memory=False, metric='euclidean',
#      metric_kwds=None, min_dist=0.1, n_components=2, n_epochs=None,
#      n_neighbors=15, negative_sample_rate=5, output_metric='euclidean',
#      output_metric_kwds=None, random_state=None, repulsion_strength=1.0,
#      set_op_mix_ratio=1.0, spread=1.0, target_metric='categorical',
#      target_metric_kwds=None, target_n_neighbors=-1, target_weight=0.5,
#      transform_queue_size=4.0, transform_seed=42, unique=False, verbose=True)
# Construct fuzzy simplicial set
# Thu Jun  4 08:18:41 2020 Finding Nearest Neighbors
# Thu Jun  4 08:18:41 2020 Building RP forest with 13 trees
# Thu Jun  4 08:18:43 2020 NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	 5  /  15
# Thu Jun  4 08:18:48 2020 Finished Nearest Neighbor Search
# ...

# %%
fig, ax = plt.subplots(1, figsize=(14, 10))
plt.scatter(*embedding_001_super.T, s=0.3, c=target_label, cmap='Spectral', alpha=1.0)
plt.setp(ax, xticks=[], yticks=[])
cbar = plt.colorbar(boundaries=np.arange(6)-0.5)
cbar.set_ticks(np.arange(5))
cbar.set_ticklabels(['0.1','0.25','1','2.5','10'])
plt.title('noise 0.01 Embedded via UMAP');

# %%
target_1 = lam_list[noise_list == 1]
data_1 = traj_list[noise_list == 1,:]

# %%
embedding_1_super = umap.UMAP(verbose = True).fit_transform(data_1, y = target_label)
# Out:
# UMAP(a=None, angular_rp_forest=False, b=None,
#      force_approximation_algorithm=False, init='spectral', learning_rate=1.0,
#      local_connectivity=1.0, low_memory=False, metric='euclidean',
#      metric_kwds=None, min_dist=0.1, n_components=2, n_epochs=None,
#      n_neighbors=15, negative_sample_rate=5, output_metric='euclidean',
#      output_metric_kwds=None, random_state=None, repulsion_strength=1.0,
#      set_op_mix_ratio=1.0, spread=1.0, target_metric='categorical',
#      target_metric_kwds=None, target_n_neighbors=-1, target_weight=0.5,
#      transform_queue_size=4.0, transform_seed=42, unique=False, verbose=True)
# Construct fuzzy simplicial set
# Thu Jun  4 08:20:16 2020 Finding Nearest Neighbors
# Thu Jun  4 08:20:16 2020 Building RP forest with 13 trees
# Thu Jun  4 08:20:18 2020 NN descent for 15 iterations
# 	 0  /  15
# 	 1  /  15
# 	 2  /  15
# 	 3  /  15
# 	 4  /  15
# 	 5  /  15
# 	 6  /  15
# 	 7  /  15
# 	 8  /  15
# 	 9  /  15
# ...

# %%
fig, ax = plt.subplots(1, figsize=(14, 10))
plt.scatter(*embedding_1_super.T, s=0.3, c=target_label, cmap='Spectral', alpha=1.0)
plt.setp(ax, xticks=[], yticks=[])
cbar = plt.colorbar(boundaries=np.arange(6)-0.5)
cbar.set_ticks(np.arange(5))
cbar.set_ticklabels(['0.1','0.25','1','2.5','10'])
plt.title('noise 1 Embedded via UMAP');

# %% [markdown]
# # Supervised training using multiple sources of noise

# %%
embedding_full_super = umap.UMAP(verbose = True).fit_transform(traj_list, y = lam_val_list)
# Out:
# UMAP(a=None, angular_rp_forest=False, b=None,
#      force_approximation_algorithm=False, init='spectral', learning_rate=1.0,
#      local_connectivity=1.0, low_memory=False, metric='euclidean',
#      metric_kwds=None, min_dist=0.1, n_components=2, n_epochs=None,
#      n_neighbors=15, negative_sample_rate=5, output_metric='euclidean',
#      output_metric_kwds=None, random_state=None, repulsion_strength=1.0,
#      set_op_mix_ratio=1.0, spread=1.0, target_metric='categorical',
#      target_metric_kwds=None, target_n_neighbors=-1, target_weight=0.5,
#      transform_queue_size=4.0, transform_seed=42, unique=False, verbose=True)
# Construct fuzzy simplicial set
# Thu Jun  4 10:14:18 2020 Finding Nearest Neighbors
# Thu Jun  4 10:14:18 2020 Building RP forest with 23 trees
# Thu Jun  4 10:14:53 2020 NN descent for 17 iterations
# 	 0  /  17
# 	 1  /  17
# 	 2  /  17
# 	 3  /  17
# 	 4  /  17
# 	 5  /  17
# 	 6  /  17
# 	 7  /  17
# ...

# %%
fig, ax = plt.subplots(1, figsize=(14, 10))
plt.scatter(*embedding_full_super.T, s=0.3, c=lam_val_list, cmap='Spectral', alpha=1.0)
plt.setp(ax, xticks=[], yticks=[])
cbar = plt.colorbar(boundaries=np.arange(6)-0.5)
cbar.set_ticks(np.arange(5))
cbar.set_ticklabels(['0.1','0.25','1','2.5','10'])
plt.title('Multiple noise - Embedded via UMAP');
